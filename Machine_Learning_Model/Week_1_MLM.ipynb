# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
columns = [
    "Severity", "Start_Time", "State", "Timezone", "Visibility(mi)", "Wind_Speed(mph)", "Precipitation(in)", 
    "Stop", "Traffic_Calming", "Traffic_Signal", "Sunrise_Sunset"
]

target = ["Severity"]

# %%
# Load the data
file_path = Path('US_Accidents_Dec21_updated.csv', index_col=False)
df = pd.read_csv(file_path)
df = df.loc[:, columns].copy()
df.head()
# Out:
#    Severity           Start_Time State    Timezone  Visibility(mi)  \
# 0         3  2016-02-08 00:37:08    OH  US/Eastern            10.0
# 1         2  2016-02-08 05:56:20    OH  US/Eastern            10.0
# 2         2  2016-02-08 06:15:39    OH  US/Eastern            10.0
# 3         2  2016-02-08 06:51:45    OH  US/Eastern            10.0
# 4         3  2016-02-08 07:53:43    OH  US/Eastern            10.0
#
#    Wind_Speed(mph)  Precipitation(in)   Stop  Traffic_Calming  Traffic_Signal  \
# 0             10.4               0.00  False            False           False
# 1              NaN               0.02  False            False           False
# 2              NaN               0.02  False            False           False
# 3              NaN                NaN  False            False           False
# 4             10.4               0.01  False            False           False
#
#   Sunrise_Sunset
# 0          Night
# 1          Night
# 2          Night
# 3          Night
# 4            Day

# %%
df.dtypes
# Out:
# Severity               int64
# Start_Time            object
# State                 object
# Timezone              object
# Visibility(mi)       float64
# Wind_Speed(mph)      float64
# Precipitation(in)    float64
# Stop                    bool
# Traffic_Calming         bool
# Traffic_Signal          bool
# Sunrise_Sunset        object
# dtype: object

# %%
df = df.dropna(axis=0, how="any")
df.head()
# Out:
#     Severity           Start_Time State    Timezone  Visibility(mi)  \
# 0          3  2016-02-08 00:37:08    OH  US/Eastern            10.0
# 4          3  2016-02-08 07:53:43    OH  US/Eastern            10.0
# 7          2  2016-02-08 11:51:46    OH  US/Eastern             0.5
# 9          2  2016-02-08 15:16:43    OH  US/Eastern             0.5
# 10         2  2016-02-08 15:43:50    OH  US/Eastern             3.0
#
#     Wind_Speed(mph)  Precipitation(in)   Stop  Traffic_Calming  \
# 0              10.4               0.00  False            False
# 4              10.4               0.01  False            False
# 7               3.5               0.08  False            False
# 9               3.5               0.05  False            False
# 10              4.6               0.03  False            False
#
#     Traffic_Signal Sunrise_Sunset
# 0            False          Night
# 4            False            Day
# 7            False            Day
# 9            False            Day
# 10           False            Day

# %%
df.shape[0]
# Out:
# 2257531

# %%
# Add 'Year' index column from 'Start_Time' column
from datetime import datetime
df['year'] = pd.DatetimeIndex(df['Start_Time']).year
df.head()
# Out:
#     Severity           Start_Time State    Timezone  Visibility(mi)  \
# 0          3  2016-02-08 00:37:08    OH  US/Eastern            10.0
# 4          3  2016-02-08 07:53:43    OH  US/Eastern            10.0
# 7          2  2016-02-08 11:51:46    OH  US/Eastern             0.5
# 9          2  2016-02-08 15:16:43    OH  US/Eastern             0.5
# 10         2  2016-02-08 15:43:50    OH  US/Eastern             3.0
#
#     Wind_Speed(mph)  Precipitation(in)   Stop  Traffic_Calming  \
# 0              10.4               0.00  False            False
# 4              10.4               0.01  False            False
# 7               3.5               0.08  False            False
# 9               3.5               0.05  False            False
# 10              4.6               0.03  False            False
#
#     Traffic_Signal Sunrise_Sunset  year
# 0            False          Night  2016
# 4            False            Day  2016
# 7            False            Day  2016
# 9            False            Day  2016
# 10           False            Day  2016

# %%
df_2019 = df.loc[(df["year"] == 2019)]
df_2019.head()
# Out:
#          Severity                     Start_Time State     Timezone  \
# 582028          4            2019-10-02 12:50:00    NJ   US/Eastern
# 1295810         4            2019-11-01 16:18:00    LA   US/Pacific
# 1568027         4  2019-06-04 16:00:00.000000000    TX   US/Central
# 1756843         4  2019-10-19 04:30:00.000000000    VA   US/Eastern
# 1935372         4            2019-12-17 09:12:52    AZ  US/Mountain
#
#          Visibility(mi)  Wind_Speed(mph)  Precipitation(in)   Stop  \
# 582028             10.0              5.0                0.0  False
# 1295810            10.0              5.0                0.0  False
# 1568027            10.0             25.0                0.0  False
# 1756843            10.0              0.0                0.0  False
# 1935372            10.0             14.0                0.0   True
#
#          Traffic_Calming  Traffic_Signal Sunrise_Sunset  year
# 582028             False           False            Day  2019
# 1295810            False            True            Day  2019
# 1568027            False           False            Day  2019
# 1756843            False           False          Night  2019
# 1935372            False           False            Day  2019

# %%
df_2019 = df_2019.drop('Start_Time', axis='columns')
df_2019.head()
# Out:
#          Severity State     Timezone  Visibility(mi)  Wind_Speed(mph)  \
# 582028          4    NJ   US/Eastern            10.0              5.0
# 1295810         4    LA   US/Pacific            10.0              5.0
# 1568027         4    TX   US/Central            10.0             25.0
# 1756843         4    VA   US/Eastern            10.0              0.0
# 1935372         4    AZ  US/Mountain            10.0             14.0
#
#          Precipitation(in)   Stop  Traffic_Calming  Traffic_Signal  \
# 582028                 0.0  False            False           False
# 1295810                0.0  False            False            True
# 1568027                0.0  False            False           False
# 1756843                0.0  False            False           False
# 1935372                0.0   True            False           False
#
#         Sunrise_Sunset  year
# 582028             Day  2019
# 1295810            Day  2019
# 1568027            Day  2019
# 1756843          Night  2019
# 1935372            Day  2019

# %%
df_2019.shape[0]
# Out:
# 200101

# %%
# Convert the target column values to short_delay and long_delay based on their values
df_2019("Severity")=list(map(lambda x: x.replace('1', 'short_delay'),))

# Convert the target column values to low_risk and high_risk based on their values
# x = {'Current': 'low_risk'}   
# df = df.replace(x)

# x = dict.fromkeys(['Late (31-120 days)', 'Late (16-30 days)', 'Default', 'In Grace Period'], 'high_risk')    
# df = df.replace(x)
# df.reset_index(inplace=True, drop=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/5h/tdj3k_294qxc447pq6_7rxn80000gn/T/ipykernel_36269/3335195424.py in <module>
#       1 # Convert the target column values to short_delay and long_delay based on their values
#       2 x = {('1','2'): '1'}
# ----> 3 df_2019 = df.replace(x)
#       4
#       5 x = dict.fromkeys(['3', '4'], '4')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    5236         method: str = "pad",
#    5237     ):
# -> 5238         return super().replace(
#    5239             to_replace=to_replace,
#    5240             value=value,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6523                 to_replace, value = keys, values
#    6524
# -> 6525             return self.replace(
#    6526                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6527             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    5236         method: str = "pad",
#    5237     ):
# -> 5238         return super().replace(
#    5239             to_replace=to_replace,
#    5240             value=value,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6572                         f"Expecting {len(to_replace)} got {len(value)} "
#    6573                     )
# -> 6574                 new_data = self._mgr.replace_list(
#    6575                     src_list=to_replace,
#    6576                     dest_list=value,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     449         inplace = validate_bool_kwarg(inplace, "inplace")
#     450
# --> 451         bm = self.apply(
#     452             "_replace_list",
#     453             src_list=src_list,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in _replace_list(self, src_list, dest_list, inplace, regex)
#     795             # in order to avoid repeating the same computations
#     796             mask = ~isna(values)
# --> 797             masks = [
#     798                 compare_or_regex_search(values, s[0], regex=regex, mask=mask)
#     799                 for s in pairs
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in <listcomp>(.0)
#     796             mask = ~isna(values)
#     797             masks = [
# --> 798                 compare_or_regex_search(values, s[0], regex=regex, mask=mask)
#     799                 for s in pairs
#     800             ]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/array_algos/replace.py in compare_or_regex_search(a, b, regex, mask)
#     112         result = tmp
#     113
# --> 114     _check_comparison_types(result, a, b)
#     115     return result
#     116
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/array_algos/replace.py in _check_comparison_types(result, a, b)
#      77             type_names[0] = f"ndarray(dtype={a.dtype})"
#      78
# ---> 79             raise TypeError(
#      80                 f"Cannot compare types {repr(type_names[0])} and {repr(type_names[1])}"
#      81             )
#
# TypeError: Cannot compare types 'ndarray(dtype=object)' and 'tuple'

# %%
df_2019.Traffic_Calming = df.Traffic_Calming.replace({True: 1, False: 0}) 
df_2019.Traffic_Signal = df.Traffic_Signal.replace({True: 1, False: 0}) 
df_2019.Stop = df.Stop.replace({True: 1, False: 0}) 

df_2019.head()

# %%
X = pd.get_dummies(df_2019, columns=['State', 'Timezone', 'Sunrise_Sunset'])
X.head()

# %% [markdown]
# # <span style='color:Blue'> <b>2020-2021 COVID YEARS</b> </span>

# %%
df_Covid = df.loc[(df["year"] >= 2020)]
df_Covid.head()

# %%
df_Covid = df_Covid.drop('Start_Time', axis='columns')
df_Covid.head()

# %%
df_Covid.shape[0]

# %%
df_Covid.Traffic_Calming = df.Traffic_Calming.replace({True: 1, False: 0}) 
df_Covid.Traffic_Signal = df.Traffic_Signal.replace({True: 1, False: 0}) 
df_Covid.Stop = df.Stop.replace({True: 1, False: 0}) 

df_Covid.head()

# %%
X = pd.get_dummies(df_Covid, columns=['State', 'Timezone', 'Sunrise_Sunset'])
X.head()
