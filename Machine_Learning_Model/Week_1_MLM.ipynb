# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
columns = [
    "Severity", "Start_Time", "State", "Timezone", "Visibility(mi)", "Wind_Speed(mph)", "Precipitation(in)", 
    "Stop", "Traffic_Calming", "Traffic_Signal", "Sunrise_Sunset"
]

target = ["Severity"]

# %%
# Load the data
file_path = Path('US_Accidents_Dec21_updated.csv', index_col=False)
df = pd.read_csv(file_path)
df = df.loc[:, columns].copy()
df.head()
# Out:
#    Severity           Start_Time State    Timezone  Visibility(mi)  \
# 0         3  2016-02-08 00:37:08    OH  US/Eastern            10.0
# 1         2  2016-02-08 05:56:20    OH  US/Eastern            10.0
# 2         2  2016-02-08 06:15:39    OH  US/Eastern            10.0
# 3         2  2016-02-08 06:51:45    OH  US/Eastern            10.0
# 4         3  2016-02-08 07:53:43    OH  US/Eastern            10.0
#
#    Wind_Speed(mph)  Precipitation(in)   Stop  Traffic_Calming  Traffic_Signal  \
# 0             10.4               0.00  False            False           False
# 1              NaN               0.02  False            False           False
# 2              NaN               0.02  False            False           False
# 3              NaN                NaN  False            False           False
# 4             10.4               0.01  False            False           False
#
#   Sunrise_Sunset
# 0          Night
# 1          Night
# 2          Night
# 3          Night
# 4            Day

# %%
df.dtypes
# Out:
# Severity               int64
# Start_Time            object
# State                 object
# Timezone              object
# Visibility(mi)       float64
# Wind_Speed(mph)      float64
# Precipitation(in)    float64
# Stop                    bool
# Traffic_Calming         bool
# Traffic_Signal          bool
# Sunrise_Sunset        object
# dtype: object

# %%
df = df.dropna(axis=0, how="any")
df.head()
# Out:
#     Severity           Start_Time State    Timezone  Visibility(mi)  \
# 0          3  2016-02-08 00:37:08    OH  US/Eastern            10.0
# 4          3  2016-02-08 07:53:43    OH  US/Eastern            10.0
# 7          2  2016-02-08 11:51:46    OH  US/Eastern             0.5
# 9          2  2016-02-08 15:16:43    OH  US/Eastern             0.5
# 10         2  2016-02-08 15:43:50    OH  US/Eastern             3.0
#
#     Wind_Speed(mph)  Precipitation(in)   Stop  Traffic_Calming  \
# 0              10.4               0.00  False            False
# 4              10.4               0.01  False            False
# 7               3.5               0.08  False            False
# 9               3.5               0.05  False            False
# 10              4.6               0.03  False            False
#
#     Traffic_Signal Sunrise_Sunset
# 0            False          Night
# 4            False            Day
# 7            False            Day
# 9            False            Day
# 10           False            Day

# %%
df.shape[0]
# Out:
# 2257531

# %%
# Add 'Year' index column from 'Start_Time' column
from datetime import datetime
df['year'] = pd.DatetimeIndex(df['Start_Time']).year
df.head()
# Out:
#     Severity           Start_Time State    Timezone  Visibility(mi)  \
# 0          3  2016-02-08 00:37:08    OH  US/Eastern            10.0
# 4          3  2016-02-08 07:53:43    OH  US/Eastern            10.0
# 7          2  2016-02-08 11:51:46    OH  US/Eastern             0.5
# 9          2  2016-02-08 15:16:43    OH  US/Eastern             0.5
# 10         2  2016-02-08 15:43:50    OH  US/Eastern             3.0
#
#     Wind_Speed(mph)  Precipitation(in)   Stop  Traffic_Calming  \
# 0              10.4               0.00  False            False
# 4              10.4               0.01  False            False
# 7               3.5               0.08  False            False
# 9               3.5               0.05  False            False
# 10              4.6               0.03  False            False
#
#     Traffic_Signal Sunrise_Sunset  year
# 0            False          Night  2016
# 4            False            Day  2016
# 7            False            Day  2016
# 9            False            Day  2016
# 10           False            Day  2016

# %%
df_2019 = df.loc[(df["year"] == 2019)]
df_2019.head()
# Out:
#          Severity                     Start_Time State     Timezone  \
# 582028          4            2019-10-02 12:50:00    NJ   US/Eastern
# 1295810         4            2019-11-01 16:18:00    LA   US/Pacific
# 1568027         4  2019-06-04 16:00:00.000000000    TX   US/Central
# 1756843         4  2019-10-19 04:30:00.000000000    VA   US/Eastern
# 1935372         4            2019-12-17 09:12:52    AZ  US/Mountain
#
#          Visibility(mi)  Wind_Speed(mph)  Precipitation(in)   Stop  \
# 582028             10.0              5.0                0.0  False
# 1295810            10.0              5.0                0.0  False
# 1568027            10.0             25.0                0.0  False
# 1756843            10.0              0.0                0.0  False
# 1935372            10.0             14.0                0.0   True
#
#          Traffic_Calming  Traffic_Signal Sunrise_Sunset  year
# 582028             False           False            Day  2019
# 1295810            False            True            Day  2019
# 1568027            False           False            Day  2019
# 1756843            False           False          Night  2019
# 1935372            False           False            Day  2019

# %%
df_2019 = df_2019.drop('Start_Time', axis='columns')
df_2019.head()
# Out:
#          Severity State     Timezone  Visibility(mi)  Wind_Speed(mph)  \
# 582028          4    NJ   US/Eastern            10.0              5.0
# 1295810         4    LA   US/Pacific            10.0              5.0
# 1568027         4    TX   US/Central            10.0             25.0
# 1756843         4    VA   US/Eastern            10.0              0.0
# 1935372         4    AZ  US/Mountain            10.0             14.0
#
#          Precipitation(in)   Stop  Traffic_Calming  Traffic_Signal  \
# 582028                 0.0  False            False           False
# 1295810                0.0  False            False            True
# 1568027                0.0  False            False           False
# 1756843                0.0  False            False           False
# 1935372                0.0   True            False           False
#
#         Sunrise_Sunset  year
# 582028             Day  2019
# 1295810            Day  2019
# 1568027            Day  2019
# 1756843          Night  2019
# 1935372            Day  2019

# %%
df_2019.shape[0]
# Out:
# 200101

# %%
df_2019.Traffic_Calming = df.Traffic_Calming.replace({True: 1, False: 0}) 
df_2019.Traffic_Signal = df.Traffic_Signal.replace({True: 1, False: 0}) 
df_2019.Stop = df.Stop.replace({True: 1, False: 0}) 

df_2019.head()
# Out:
#          Severity State     Timezone  Visibility(mi)  Wind_Speed(mph)  \
# 582028          4    NJ   US/Eastern            10.0              5.0
# 1295810         4    LA   US/Pacific            10.0              5.0
# 1568027         4    TX   US/Central            10.0             25.0
# 1756843         4    VA   US/Eastern            10.0              0.0
# 1935372         4    AZ  US/Mountain            10.0             14.0
#
#          Precipitation(in)  Stop  Traffic_Calming  Traffic_Signal  \
# 582028                 0.0     0                0               0
# 1295810                0.0     0                0               1
# 1568027                0.0     0                0               0
# 1756843                0.0     0                0               0
# 1935372                0.0     1                0               0
#
#         Sunrise_Sunset  year
# 582028             Day  2019
# 1295810            Day  2019
# 1568027            Day  2019
# 1756843          Night  2019
# 1935372            Day  2019

# %%
X = pd.get_dummies(df_2019, columns=['State', 'Timezone', 'Sunrise_Sunset'])
X.head()
# Out:
#          Severity  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  Stop  \
# 582028          4            10.0              5.0                0.0     0
# 1295810         4            10.0              5.0                0.0     0
# 1568027         4            10.0             25.0                0.0     0
# 1756843         4            10.0              0.0                0.0     0
# 1935372         4            10.0             14.0                0.0     1
#
#          Traffic_Calming  Traffic_Signal  year  State_AL  State_AR  ...  \
# 582028                 0               0  2019         0         0  ...
# 1295810                0               1  2019         0         0  ...
# 1568027                0               0  2019         0         0  ...
# 1756843                0               0  2019         0         0  ...
# 1935372                0               0  2019         0         0  ...
#
#          State_WA  State_WI  State_WV  State_WY  Timezone_US/Central  \
# 582028          0         0         0         0                    0
# 1295810         0         0         0         0                    0
# 1568027         0         0         0         0                    1
# 1756843         0         0         0         0                    0
# 1935372         0         0         0         0                    0
#
#          Timezone_US/Eastern  Timezone_US/Mountain  Timezone_US/Pacific  \
# 582028                     1                     0                    0
# 1295810                    0                     0                    1
# 1568027                    0                     0                    0
# 1756843                    1                     0                    0
# 1935372                    0                     1                    0
#
#          Sunrise_Sunset_Day  Sunrise_Sunset_Night
# 582028                    1                     0
# 1295810                   1                     0
# 1568027                   1                     0
# 1756843                   0                     1
# 1935372                   1                     0
#
# [5 rows x 63 columns]

# %% [markdown]
# # <span style='color:Blue'> <b>2020-2021 COVID YEARS</b> </span>

# %%
df_Covid = df.loc[(df["year"] >= 2020)]
df_Covid.head()
# Out:
#         Severity           Start_Time State    Timezone  Visibility(mi)  \
# 224945         2  2021-03-10 19:57:00    MA  US/Eastern            10.0
# 224946         2  2021-07-30 23:37:00    CA  US/Pacific             2.0
# 224947         2  2021-10-15 16:42:36    MD  US/Eastern            10.0
# 224948         2  2021-12-21 11:42:00    WA  US/Pacific            10.0
# 224949         2  2021-12-09 08:51:00    CA  US/Pacific            10.0
#
#         Wind_Speed(mph)  Precipitation(in)   Stop  Traffic_Calming  \
# 224945             12.0                0.0  False            False
# 224946              6.0                0.0  False            False
# 224947              9.0                0.0  False            False
# 224948              0.0                0.0  False            False
# 224949              9.0                0.0  False            False
#
#         Traffic_Signal Sunrise_Sunset  year
# 224945           False          Night  2021
# 224946           False          Night  2021
# 224947           False            Day  2021
# 224948           False            Day  2021
# 224949           False            Day  2021

# %%
df_Covid = df_Covid.drop('Start_Time', axis='columns')
df_Covid.head()
# Out:
#         Severity State    Timezone  Visibility(mi)  Wind_Speed(mph)  \
# 224945         2    MA  US/Eastern            10.0             12.0
# 224946         2    CA  US/Pacific             2.0              6.0
# 224947         2    MD  US/Eastern            10.0              9.0
# 224948         2    WA  US/Pacific            10.0              0.0
# 224949         2    CA  US/Pacific            10.0              9.0
#
#         Precipitation(in)   Stop  Traffic_Calming  Traffic_Signal  \
# 224945                0.0  False            False           False
# 224946                0.0  False            False           False
# 224947                0.0  False            False           False
# 224948                0.0  False            False           False
# 224949                0.0  False            False           False
#
#        Sunrise_Sunset  year
# 224945          Night  2021
# 224946          Night  2021
# 224947            Day  2021
# 224948            Day  2021
# 224949            Day  2021

# %%
df_Covid.shape[0]
# Out:
# 2005591

# %%
df_Covid.Traffic_Calming = df.Traffic_Calming.replace({True: 1, False: 0}) 
df_Covid.Traffic_Signal = df.Traffic_Signal.replace({True: 1, False: 0}) 
df_Covid.Stop = df.Stop.replace({True: 1, False: 0}) 

df_Covid.head()
# Out:
#         Severity State    Timezone  Visibility(mi)  Wind_Speed(mph)  \
# 224945         2    MA  US/Eastern            10.0             12.0
# 224946         2    CA  US/Pacific             2.0              6.0
# 224947         2    MD  US/Eastern            10.0              9.0
# 224948         2    WA  US/Pacific            10.0              0.0
# 224949         2    CA  US/Pacific            10.0              9.0
#
#         Precipitation(in)  Stop  Traffic_Calming  Traffic_Signal  \
# 224945                0.0     0                0               0
# 224946                0.0     0                0               0
# 224947                0.0     0                0               0
# 224948                0.0     0                0               0
# 224949                0.0     0                0               0
#
#        Sunrise_Sunset  year
# 224945          Night  2021
# 224946          Night  2021
# 224947            Day  2021
# 224948            Day  2021
# 224949            Day  2021

# %%
X = pd.get_dummies(df_Covid, columns=['State', 'Timezone', 'Sunrise_Sunset'])
X.head()
# Out:
#         Severity  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  Stop  \
# 224945         2            10.0             12.0                0.0     0
# 224946         2             2.0              6.0                0.0     0
# 224947         2            10.0              9.0                0.0     0
# 224948         2            10.0              0.0                0.0     0
# 224949         2            10.0              9.0                0.0     0
#
#         Traffic_Calming  Traffic_Signal  year  State_AL  State_AR  ...  \
# 224945                0               0  2021         0         0  ...
# 224946                0               0  2021         0         0  ...
# 224947                0               0  2021         0         0  ...
# 224948                0               0  2021         0         0  ...
# 224949                0               0  2021         0         0  ...
#
#         State_WA  State_WI  State_WV  State_WY  Timezone_US/Central  \
# 224945         0         0         0         0                    0
# 224946         0         0         0         0                    0
# 224947         0         0         0         0                    0
# 224948         1         0         0         0                    0
# 224949         0         0         0         0                    0
#
#         Timezone_US/Eastern  Timezone_US/Mountain  Timezone_US/Pacific  \
# 224945                    1                     0                    0
# 224946                    0                     0                    1
# 224947                    1                     0                    0
# 224948                    0                     0                    1
# 224949                    0                     0                    1
#
#         Sunrise_Sunset_Day  Sunrise_Sunset_Night
# 224945                   0                     1
# 224946                   0                     1
# 224947                   1                     0
# 224948                   1                     0
# 224949                   1                     0
#
# [5 rows x 63 columns]
